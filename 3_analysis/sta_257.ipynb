# %% [markdown]
# # Experiments with 257 cells

# %% [markdown]
# ## Differences between Epithelial Tissues

# %% [markdown]
# We would like to see if there are significant differences between the distributions followed by these variables in each of the epithelial tissues. In order to do that, we first perform a Kruskal-Wallis test over the six tissues for each of the variables, and then a pairwise Dunn test. Sice we repeat this test over 22 variables, we have fixed the p-value threshold in 0.01.

# %% [markdown]
# #### Kruskal-Wallis pvalues

# %% [markdown]
# We are calculating the p-values from the Kruskal-Wallis test. First, we load the frame

# %%
require("dunn.test")
cellNumber <- 257
load(paste("../2_variables/frames",as.character(cellNumber), "cells_frame.RData", sep="/"))
colNames <- colnames(cells_frame)
# Out:
# Loading required package: dunn.test

# %% [markdown]
# and save the pvalues in an array

# %%
KWpvalue <- c()
for (j in seq(2,length(cells_frame))){
  colName <- colNames[j]
  kwAux <- as.numeric(kruskal.test(cells_frame[,colName] ~ cells_frame$type)[3])
  KWpvalue <- c(KWpvalue, kwAux)
    }

# %% [markdown]
# The variables whith a p-value greater or equal than 0.01 are

# %%
#Note the first entry in colNames is type and we do not want to take it.
colNames[c(FALSE,KWpvalue<=0.01)]
validCols <- colNames[c(FALSE, KWpvalue<=0.01)]
# Out:
#  [1] "PE.0.sub"          "PE.1.sub"          "landscape.0.2.sub"
#  [4] "landscape.0.5.sub" "lan.0.05.sub"      "lan.0.10.sub"
#  [7] "lan.0.15.sub"      "landscape.1.1.sub" "landscape.1.2.sub"
# [10] "max.0.1.2.sub"     "max.0.1.3.sub"     "max.0.2.1.sub"
# [13] "max.0.2.2.sub"     "max.0.2.3.sub"     "MAX.0.2.10.sub"
# [16] "max.1.1.1.sub"     "max.1.2.1.sub"     "max.1.1.2.sub"
# [19] "MAX.1.1.02.sub"    "MAX.1.1.03.sub"    "PE.1.sup"
# [22] "landscape.0.2.sup" "lan.0.02.sup"      "landscape.1.1.sup"
# [25] "landscape.1.2.sup" "lan.1.02.sup"      "max.0.1.1.sup"
# [28] "max.0.1.2.sup"     "MAX.0.1.02.sup"    "max.0.2.1.sup"
# [31] "max.0.2.2.sup"     "MAX.0.2.02.sup"    "max.1.1.1.sup"
# [34] "max.1.2.1.sup"     "MAX.1.2.02.sup"    "MAX.1.2.02.sup.1"
# [37] "PE.0.rips"         "len.1"             "len.2"
# [40] "len.5"             "LEN.15"            "LEN.20"
# [43] "max.0.1.1.rips"    "LEN.05"            "LEN.10"
# [46] "max.0.1.2.rips"    "max.0.1.3.rips"    "MAX.0.1.05.rips"
# [49] "MAX.0.1.10.rips"   "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# The variables with a p-value greater than 0.01 are

# %%
#Note the first entry in colNames is type and we do not want to take it.
colNames[c(FALSE,KWpvalue>0.01)]
# Out:
# [1] "lan.1.03.sub"  "lan.1.05.sub"  "max.0.1.1.sub" "PE.0.sup"
# [5] "lan.0.03.sup"  "LEN.50"

# %% [markdown]
# There are none variables with p-value greater than 0.01

# %% [markdown]
# #### Dunn Test

# %% [markdown]
# We run the Dunn test to compare pairwise the tissues.

# %%
colNames <- colnames(cells_frame)

# we perform the first dunn test before the loop to set the row names
colName <- colNames[2]
x1 <- cells_frame[cells_frame$type == 'cNT', colName]
x2 <- cells_frame[cells_frame$type == 'dWL', colName]
x3 <- cells_frame[cells_frame$type == 'dWP', colName]
x4 <- cells_frame[cells_frame$type == 'dNP', colName]
w <- c(x1, x2, x3, x4)
g <- factor(rep(1:4, c(length(x1),length(x2),length(x3),length(x4))),
            labels = c("cNT","dWL","dWP",'dNP'))

P <- dunn.test(w, g)

Pvalues <- data.frame(P$P.adjusted)
colnames(Pvalues) <- c(colNames[2])
row.names(Pvalues) <- P[["comparisons"]]

for (j in seq(3,length(cells_frame))){
  colName <- colNames[j]
  x1 <- cells_frame[cells_frame$type == 'cNT', colName]
  x2 <- cells_frame[cells_frame$type == 'dWL', colName]
  x3 <- cells_frame[cells_frame$type == 'dWP', colName]
  x4 <- cells_frame[cells_frame$type == 'dNP', colName]
  w <- c(x1, x2, x3, x4)
  g <- factor(rep(1:4, c(length(x1),length(x2),length(x3),length(x4))),
              labels = c("cNT","dWL","dWP",'dNP'))
    
  P <- dunn.test(w, g)
  Pvalues[colName] <- P$P.adjusted
}
# Out:
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 36.491, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.760775
#          |    0.0001*
#          |
#      dWL |   4.322750   0.303168
#          |    0.0000*     0.3809
#          |
#      dWP |   5.738061   1.551637   1.322003
#          |    0.0000*     0.0604     0.0931
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 16.2534, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |  -3.432175
#          |    0.0003*
#          |
#      dWL |  -2.969152   0.628913
#          |    0.0015*     0.2647
#          |
#      dWP |  -3.252568   0.420882  -0.230525
#          |    0.0006*     0.3369     0.4088
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 30.7026, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.238716
#          |    0.0000*
#          |
#      dWL |   3.735472  -0.713059
#          |    0.0001*     0.2379
#          |
#      dWP |   5.034716   0.422524   1.217373
#          |    0.0000*     0.3363     0.1117
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 25.6594, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.187521
#          |    0.0000*
#          |
#      dWL |   3.993378  -0.423253
#          |    0.0000*     0.3361
#          |
#      dWP |   4.022031  -0.463843  -0.036749
#          |    0.0000*     0.3214     0.4853
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 35.5351, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   5.125052
#          |    0.0000*
#          |
#      dWL |   4.608048  -0.777281
#          |    0.0000*     0.2185
#          |
#      dWP |   4.550893  -0.911743  -0.131158
#          |    0.0000*     0.1810     0.4478
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 43.7038, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   5.473277
#          |    0.0000*
#          |
#      dWL |   4.299784  -1.406692
#          |    0.0000*     0.0798
#          |
#      dWP |   5.744320  -0.155070   1.351125
#          |    0.0000*     0.4384     0.0883
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 42.4317, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   5.049449
#          |    0.0000*
#          |
#      dWL |   4.952621  -0.382986
#          |    0.0000*     0.3509
#          |
#      dWP |   5.628837   0.161841   0.584684
#          |    0.0000*     0.4357     0.2794
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 23.8956, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.497401
#          |    0.0002*
#          |
#      dWL |   4.399635   0.634204
#          |    0.0000*     0.2630
#          |
#      dWP |   3.701638  -0.070350  -0.758189
#          |    0.0001*     0.4720     0.2242
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 37.6251, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.664604
#          |    0.0000*
#          |
#      dWL |   4.120753  -0.775465
#          |    0.0000*     0.2190
#          |
#      dWP |   5.593991   0.514424   1.382272
#          |    0.0000*     0.3035     0.0834
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 6.9803, df = 3, p-value = 0.07
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |  -0.880358
#          |     0.1893
#          |
#      dWL |  -0.951355  -0.014775
#          |     0.1707     0.4941
#          |
#      dWP |   1.395996   2.172800   2.324651
#          |     0.0814    0.0149*    0.0100*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 0.7921, df = 3, p-value = 0.85
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |  -0.720845
#          |     0.2355
#          |
#      dWL |   0.091912   0.796055
#          |     0.4634     0.2130
#          |
#      dWP |   0.000000   0.720845  -0.091912
#          |     0.5000     0.2355     0.4634
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 1.0365, df = 3, p-value = 0.79
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.267504
#          |     0.3945
#          |
#      dWL |  -0.567480  -0.790362
#          |     0.2852     0.2147
#          |
#      dWP |   0.380180   0.084474   0.941479
#          |     0.3519     0.4663     0.1732
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 15.0065, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.360781
#          |    0.0004*
#          |
#      dWL |   2.450325  -1.039969
#          |    0.0071*     0.1492
#          |
#      dWP |   3.228776  -0.371514   0.725947
#          |    0.0006*     0.3551     0.2339
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 17.7751, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.747527
#          |    0.0001*
#          |
#      dWL |   2.690635  -1.198307
#          |    0.0036*     0.1154
#          |
#      dWP |   3.395798  -0.603628   0.649942
#          |    0.0003*     0.2730     0.2579
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 18.4832, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.367059
#          |    0.0004*
#          |
#      dWL |   3.484469  -0.086513
#          |    0.0002*     0.4655
#          |
#      dWP |   3.518375  -0.109676  -0.023307
#          |    0.0002*     0.4563     0.4907
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 18.1752, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.611158
#          |    0.0002*
#          |
#      dWL |   3.143061  -0.644013
#          |    0.0008*     0.2598
#          |
#      dWP |   3.459571  -0.408217   0.260253
#          |    0.0003*     0.3416     0.3973
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 24.9327, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.307178
#          |    0.0000*
#          |
#      dWL |   3.869287  -0.656388
#          |    0.0001*     0.2558
#          |
#      dWP |   3.778112  -0.809326  -0.152612
#          |    0.0001*     0.2092     0.4394
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 35.9832, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.917798
#          |    0.0000*
#          |
#      dWL |   4.083018  -1.060133
#          |    0.0000*     0.1445
#          |
#      dWP |   5.200163  -0.103381   1.032584
#          |    0.0000*     0.4588     0.1509
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 13.9787, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   2.574795
#          |    0.0050*
#          |
#      dWL |   3.455163   0.667473
#          |    0.0003*     0.2522
#          |
#      dWP |   2.730735  -0.046626  -0.768833
#          |    0.0032*     0.4814     0.2210
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 25.2827, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.724421
#          |    0.0001*
#          |
#      dWL |   3.317117  -0.594174
#          |    0.0005*     0.2762
#          |
#      dWP |   4.655640   0.585864   1.262816
#          |    0.0000*     0.2790     0.1033
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 16.5532, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   2.943426
#          |    0.0016*
#          |
#      dWL |   3.398632   0.251539
#          |    0.0003*     0.4007
#          |
#      dWP |   3.413695   0.217042  -0.040447
#          |    0.0003*     0.4141     0.4839
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 16.6711, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   2.561528
#          |    0.0052*
#          |
#      dWL |   2.843733   0.113171
#          |    0.0022*     0.4549
#          |
#      dWP |   3.902029   1.051048   0.994844
#          |    0.0000*     0.1466     0.1599
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 19.8952, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   2.648644
#          |    0.0040*
#          |
#      dWL |   2.602246  -0.196816
#          |    0.0046*     0.4220
#          |
#      dWP |   4.394948   1.420287   1.721234
#          |    0.0000*     0.0778     0.0426
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 8.5125, df = 3, p-value = 0.04
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |  -2.418917
#          |    0.0078*
#          |
#      dWL |  -2.501388   0.063894
#          |    0.0062*     0.4745
#          |
#      dWP |  -1.976273   0.589243   0.557251
#          |    0.0241*     0.2778     0.2887
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 8.9015, df = 3, p-value = 0.03
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.204005
#          |     0.1143
#          |
#      dWL |   2.223125   0.875808
#          |    0.0131*     0.1906
#          |
#      dWP |   2.789671   1.378728   0.521182
#          |    0.0026*     0.0840     0.3011
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 40.767, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.903413
#          |    0.0000*
#          |
#      dWL |   4.142310  -0.990928
#          |    0.0000*     0.1609
#          |
#      dWP |   5.830938   0.494987   1.593809
#          |    0.0000*     0.3103     0.0555
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 14.252, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.430767
#          |     0.0762
#          |
#      dWL |   1.680687   0.148856
#          |     0.0464     0.4408
#          |
#      dWP |   3.757891   2.048364   2.016096
#          |    0.0001*    0.0203*    0.0219*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 7.6875, df = 3, p-value = 0.05
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.341816
#          |     0.3662
#          |
#      dWL |  -0.235012  -0.555118
#          |     0.4071     0.2894
#          |
#      dWP |   2.269521   1.759351   2.467628
#          |    0.0116*     0.0393    0.0068*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 35.2593, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.679875
#          |    0.0000*
#          |
#      dWL |   3.665131  -1.213320
#          |    0.0001*     0.1125
#          |
#      dWP |   5.380062   0.301094   1.627444
#          |    0.0000*     0.3817     0.0518
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 37.87, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.941183
#          |    0.0000*
#          |
#      dWL |   3.965903  -1.191869
#          |    0.0000*     0.1167
#          |
#      dWP |   5.480801   0.133052   1.425773
#          |    0.0000*     0.4471     0.0770
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 33.7434, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.756898
#          |    0.0001*
#          |
#      dWL |   3.388479  -0.559975
#          |    0.0004*     0.2877
#          |
#      dWP |   5.655216   1.478814   2.174776
#          |    0.0000*     0.0696    0.0148*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 29.5469, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.940607
#          |    0.0000*
#          |
#      dWL |   4.834623   0.600849
#          |    0.0000*     0.2740
#          |
#      dWP |   4.174068  -0.076171  -0.728431
#          |    0.0000*     0.4696     0.2332
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 26.9918, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.865416
#          |    0.0001*
#          |
#      dWL |   4.239114   0.122379
#          |    0.0000*     0.4513
#          |
#      dWP |   4.385487   0.194756   0.075059
#          |    0.0000*     0.4228     0.4701
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 26.8864, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.554254
#          |    0.0002*
#          |
#      dWL |   3.856222   0.073880
#          |    0.0001*     0.4706
#          |
#      dWP |   4.772192   0.863937   0.838368
#          |    0.0000*     0.1938     0.2009
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 25.1751, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.768084
#          |    0.0001*
#          |
#      dWL |   3.080111  -0.857158
#          |    0.0010*     0.1957
#          |
#      dWP |   4.661074   0.547232   1.505167
#          |    0.0000*     0.2921     0.0661
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 25.446, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   3.502720
#          |    0.0002*
#          |
#      dWL |   3.134250  -0.545267
#          |    0.0009*     0.2928
#          |
#      dWP |   4.811001   0.951402   1.598518
#          |    0.0000*     0.1707     0.0550
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 24.0424, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   2.943701
#          |    0.0016*
#          |
#      dWL |   2.774333  -0.328056
#          |    0.0028*     0.3714
#          |
#      dWP |   4.832511   1.530334   1.979595
#          |    0.0000*     0.0630    0.0239*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 37.8332, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.695639
#          |    0.0000*
#          |
#      dWL |   4.068276  -0.854762
#          |    0.0000*     0.1963
#          |
#      dWP |   5.615707   0.503495   1.456112
#          |    0.0000*     0.3073     0.0727
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 37.4745, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.741497
#          |    0.0000*
#          |
#      dWL |   3.974473  -0.987024
#          |    0.0000*     0.1618
#          |
#      dWP |   5.565037   0.410726   1.500069
#          |    0.0000*     0.3406     0.0668
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 36.5702, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.252500
#          |    0.0000*
#          |
#      dWL |   3.379876  -1.056628
#          |    0.0004*     0.1453
#          |
#      dWP |   5.778741   1.097574   2.304894
#          |    0.0000*     0.1362    0.0106*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 36.5702, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   4.252500
#          |    0.0000*
#          |
#      dWL |   3.379876  -1.056628
#          |    0.0004*     0.1453
#          |
#      dWP |   5.778741   1.097574   2.304894
#          |    0.0000*     0.1362    0.0106*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 29.2075, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |  -1.651667
#          |     0.0493
#          |
#      dWL |  -4.484687  -2.533047
#          |    0.0000*    0.0057*
#          |
#      dWP |  -4.559505  -2.569613  -0.000674
#          |    0.0000*    0.0051*     0.4997
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 11.259, df = 3, p-value = 0.01
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.667019
#          |     0.2524
#          |
#      dWL |   2.199143   1.383028
#          |    0.0139*     0.0833
#          |
#      dWP |   3.056824   2.163049   0.807972
#          |    0.0011*    0.0153*     0.2096
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 11.3133, df = 3, p-value = 0.01
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.682901
#          |     0.2473
#          |
#      dWL |   2.081019   1.257754
#          |    0.0187*     0.1042
#          |
#      dWP |   3.118578   2.204341   0.986847
#          |    0.0009*    0.0138*     0.1619
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 15.9214, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.679724
#          |     0.2483
#          |
#      dWL |   2.315243   1.478237
#          |    0.0103*     0.0697
#          |
#      dWP |   3.694949   2.741133   1.319621
#          |    0.0001*    0.0031*     0.0935
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 29.5175, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.895712
#          |     0.1852
#          |
#      dWL |   4.264637   3.074232
#          |    0.0000*    0.0011*
#          |
#      dWP |   4.394827   3.173107   0.058724
#          |    0.0000*    0.0008*     0.4766
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 30.7385, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.054526
#          |     0.1458
#          |
#      dWL |   4.581886   3.212034
#          |    0.0000*    0.0007*
#          |
#      dWP |   4.343366   2.966649  -0.309149
#          |    0.0000*    0.0015*     0.3786
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 3.7096, df = 3, p-value = 0.29
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.550026
#          |     0.0606
#          |
#      dWL |   1.093496  -0.513624
#          |     0.1371     0.3038
#          |
#      dWP |  -0.020584  -1.569084  -1.113746
#          |     0.4918     0.0583     0.1327
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 11.259, df = 3, p-value = 0.01
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.667019
#          |     0.2524
#          |
#      dWL |   2.199143   1.383028
#          |    0.0139*     0.0833
#          |
#      dWP |   3.056824   2.163049   0.807972
#          |    0.0011*    0.0153*     0.2096
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 19.5121, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.019587
#          |     0.1540
#          |
#      dWL |   3.370265   2.122147
#          |    0.0004*    0.0169*
#          |
#      dWP |   3.818457   2.515617   0.386098
#          |    0.0001*    0.0059*     0.3497
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 27.0133, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.057702
#          |     0.1451
#          |
#      dWL |   4.072263   2.735991
#          |    0.0000*    0.0031*
#          |
#      dWP |   4.333073   2.953944   0.190349
#          |    0.0000*    0.0016*     0.4245
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 11.5501, df = 3, p-value = 0.01
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.838539
#          |     0.2009
#          |
#      dWL |   2.151893   1.170062
#          |    0.0157*     0.1210
#          |
#      dWP |   3.190624   2.115405   0.986847
#          |    0.0007*    0.0172*     0.1619
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 12.3387, df = 3, p-value = 0.01
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.848067
#          |     0.1982
#          |
#      dWL |   2.245718   1.247732
#          |    0.0124*     0.1061
#          |
#      dWP |   3.283255   2.191636   0.984147
#          |    0.0005*    0.0142*     0.1625
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 16.3915, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   0.956061
#          |     0.1695
#          |
#      dWL |   2.735767   1.595995
#          |    0.0031*     0.0552
#          |
#      dWP |   3.715533   2.483854   0.919347
#          |    0.0001*    0.0065*     0.1790
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 20.155, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.070407
#          |     0.1422
#          |
#      dWL |   3.345965   2.049488
#          |    0.0004*    0.0202*
#          |
#      dWP |   3.952257   2.588671   0.542023
#          |    0.0000*    0.0048*     0.2939
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 24.3571, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.041821
#          |     0.1487
#          |
#      dWL |   3.788089   2.487948
#          |    0.0001*    0.0064*
#          |
#      dWP |   4.199273   2.845950   0.342899
#          |    0.0000*    0.0022*     0.3658
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 29.1398, df = 3, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cNT        dNP        dWL
# ---------+---------------------------------
#      dNP |   1.422975
#          |     0.0774
#          |
#      dWL |   4.382087   2.663332
#          |    0.0000*    0.0039*
#          |
#      dWP |   4.538920   2.779248   0.083024
#          |    0.0000*    0.0027*     0.4669
#
# alpha = 0.05
# Reject Ho if p <= alpha/2

# %% [markdown]
# We only consider the variables with a p-value greater than 0.01 in the Kruskal-Wallis test

# %%
cols <- colnames(Pvalues)%in%validCols

# %% [markdown]
# ##### Summary:

# %% [markdown]
# - cEE is differentiated from cNT only by the network distribution, and from dNP, dWL, dWP by both: network and centroids
# - cNT is differentiated from cEE and dNP only by the network distribution, and from dNP, dWL by both: network and centroids
# - dWL is differentiated from dNP by centroids; from cNT and cEE by both, network and centroids. There are not significant differences with dWP.
# - dWP is differentiated from dNP by centroids; from cNT and cEE by both, network and centroids. It cannot be differentiated from dWL.
# - dNP is differentiated from cNT by network distribution; from cEE by both, network and centroids and from dWL and dWP by centroids.

# %% [markdown]
# ##### cNT vs dNP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["cNT - dNP",cols & Pvalues["cNT - dNP",]<=0.01]
# Out:
#           PE.0.sub     PE.1.sub     landscape.0.2.sub landscape.0.5.sub
# cNT - dNP 8.469372e-05 0.0002993798 1.124005e-05      1.410087e-05
#           lan.0.05.sub lan.0.10.sub lan.0.15.sub landscape.1.1.sub
# cNT - dNP 1.487277e-07 2.208937e-08 2.215424e-07 0.0002349069
#           landscape.1.2.sub max.0.1.2.sub ... max.0.1.1.sup max.0.1.2.sup
# cNT - dNP 1.546052e-06      0.0003886114  ... 4.063769e-05  5.544999e-05
#           MAX.0.1.02.sup max.0.2.1.sup max.0.2.2.sup MAX.0.2.02.sup
# cNT - dNP 0.0001895261   8.225259e-05  0.0002302664  0.001621564
#           max.1.1.1.sup max.1.2.1.sup MAX.1.2.02.sup MAX.1.2.02.sup.1
# cNT - dNP 1.328867e-06  1.060719e-06  1.056985e-05   1.056985e-05

# %% [markdown]
# We can find differences only in the contact network

# %% [markdown]
# ##### cNT vs dWL

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["cNT - dWL",cols & Pvalues["cNT - dWL",]<=0.01]
# Out:
#           PE.0.sub    PE.1.sub    landscape.0.2.sub landscape.0.5.sub
# cNT - dWL 7.70479e-06 0.001493112 9.368157e-05      3.256924e-05
#           lan.0.05.sub lan.0.10.sub lan.0.15.sub landscape.1.1.sub
# cNT - dWL 2.032333e-06 8.548197e-06 3.661022e-07 5.421652e-06
#           landscape.1.2.sub max.0.1.2.sub ... MAX.1.2.02.sup.1 PE.0.rips
# cNT - dWL 1.88818e-05       0.007136355   ... 0.0003625917     3.65105e-06
#           LEN.15       LEN.20       LEN.05       LEN.10       MAX.0.1.05.rips
# cNT - dWL 1.001134e-05 2.303996e-06 0.0003754792 2.327925e-05 0.003111752
#           MAX.0.1.10.rips MAX.0.1.20.rips MAX.0.1.50.rips
# cNT - dWL 0.0004099832    7.59052e-05     5.877382e-06

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### dNP vs dWL

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dNP - dWL",cols & Pvalues["dNP - dWL",]<=0.01]
# Out:
#           PE.0.rips   LEN.15      LEN.20       LEN.10      MAX.0.1.20.rips
# dNP - dWL 0.005653788 0.001055225 0.0006589938 0.003109631 0.00642412
#           MAX.0.1.50.rips
# dNP - dWL 0.003868547

# %% [markdown]
# We cannot find differences between dNP and dWL

# %% [markdown]
# ##### cNT - dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["cNT - dWP",cols & Pvalues["cNT - dWP",]<=0.01]
# Out:
#           PE.0.sub     PE.1.sub     landscape.0.2.sub landscape.0.5.sub
# cNT - dWP 4.788309e-09 0.0005718349 2.392783e-07      2.884914e-05
#           lan.0.05.sub lan.0.10.sub lan.0.15.sub landscape.1.1.sub
# cNT - dWP 2.670933e-06 4.614546e-09 9.071409e-09 0.0001071057
#           landscape.1.2.sub max.0.1.2.sub ... LEN.20       max.0.1.1.rips
# cNT - dWP 1.10954e-08       0.0006216042  ... 7.015795e-06 0.001118477
#           LEN.05       LEN.10       max.0.1.2.rips max.0.1.3.rips
# cNT - dWP 6.714447e-05 7.352085e-06 0.0007098283   0.000513078
#           MAX.0.1.05.rips MAX.0.1.10.rips MAX.0.1.20.rips MAX.0.1.50.rips
# cNT - dWP 0.0001013876    3.870869e-05    1.338863e-05    2.827145e-06

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### dNP vs dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dNP - dWP",cols & Pvalues["dNP - dWP",]<=0.01]
# Out:
#           PE.0.rips   len.5       LEN.15       LEN.20     LEN.05
# dNP - dWP 0.005090596 0.003061383 0.0007540823 0.00150532 0.00594121
#           LEN.10      MAX.0.1.05.rips MAX.0.1.10.rips MAX.0.1.20.rips
# dNP - dWP 0.001568703 0.00649845      0.004817346     0.002213953
#           MAX.0.1.50.rips
# dNP - dWP 0.00272424

# %% [markdown]
# We can find differences between dNP and dWP

# %% [markdown]
# ##### dWL vs dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dWL - dWP",cols & Pvalues["dWL - dWP",]<=0.01]
# Out:
#
# dWL - dWP

# %% [markdown]
# We cannot find differences between dNP and dWP

# %% [markdown]
# ## Differences between CVT path and Epithelial tissues

# %% [markdown]
# Some steps of the CVT paths are though to represent well the contact network of some epithelial tissues.
# In particular, cNT is similar to CVT001, dWL is similar to CVT004 and dWP is similar to CVT005.

# %% [markdown]
# We will perform Mann-Whitney U tests to see if we can find significant differences in their contact network and centroid distribution with our method.

# %%
variables <- colnames(cells_frame)
variables <- variables[seq(2,length(variables))]
CVTvsEPI <- data.frame(variables)

#calculate p-values of the Mann-Whitney U test
aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'cNT', colName]
  cvt = cells_frame[cells_frame$type == 'CVT001', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["001vsCNT"] <- aux

aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'dWL', colName]
  cvt = cells_frame[cells_frame$type == 'CVT004', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["004vsDWL"] <- aux

aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'dWP', colName]
  cvt = cells_frame[cells_frame$type == 'CVT005', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["005vsDWP"] <- aux

# %% [markdown]
# ##### Summary:
# cNT and dWP can be differentiated from CVT001 and CVT005 respectively by both, network and centroid distribution. dWL can be differentiated from CVT004 only by network distribution

# %% [markdown]
# ##### cNT vs CVT001

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "001vsCNT"]<=0.01, c("variables", "001vsCNT")])
# Out:
#    variables       001vsCNT
# 1  PE.0.sub        5.519762e-04
# 6  lan.0.10.sub    3.515385e-03
# 7  lan.0.15.sub    8.710074e-05
# 18 MAX.0.2.10.sub  3.524482e-03
# 42 PE.0.rips       3.231585e-03
# 44 len.2           1.713749e-03
# 45 len.5           1.713749e-03
# 46 LEN.15          4.902788e-04
# 47 LEN.20          1.713749e-03
# 50 LEN.05          4.381588e-03
# 51 LEN.10          5.342445e-03
# 52 max.0.1.2.rips  4.381588e-03
# 53 max.0.1.3.rips  3.962480e-03
# 54 MAX.0.1.05.rips 7.831876e-04
# 55 MAX.0.1.10.rips 1.101765e-03
# 56 MAX.0.1.20.rips 4.350618e-04
# 57 MAX.0.1.50.rips 1.376707e-03

# %% [markdown]
# We can find differences in both, the contact network and the centroid distribution

# %% [markdown]
# ##### dWL vs CVT004

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "004vsDWL"]<=0.01, c("variables", "004vsDWL")])
# Out:
#    variables       004vsDWL
# 42 PE.0.rips       0.003537936
# 43 len.1           0.002555707
# 44 len.2           0.003537936
# 45 len.5           0.003537936
# 49 max.0.1.1.rips  0.002555707
# 52 max.0.1.2.rips  0.001632705
# 53 max.0.1.3.rips  0.003934908
# 54 MAX.0.1.05.rips 0.005959526

# %% [markdown]
# ##### dWP vs CVT005

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "005vsDWP"]<=0.01, c("variables", "005vsDWP")])
# Out:
#    variables       005vsDWP
# 42 PE.0.rips       1.852999e-05
# 46 LEN.15          1.232172e-03
# 47 LEN.20          2.359686e-04
# 51 LEN.10          1.536739e-03
# 52 max.0.1.2.rips  9.469782e-03
# 53 max.0.1.3.rips  6.489705e-03
# 55 MAX.0.1.10.rips 9.469782e-03
# 56 MAX.0.1.20.rips 1.101765e-03
# 57 MAX.0.1.50.rips 1.835100e-04
