# %% [markdown]
# # Experiments with 187 cells

# %% [markdown]
# ## Differences between Epithelial Tissues

# %% [markdown]
# We would like to see if there are significant differences between the distributions followed by these variables in each of the epithelial tissues. In order to do that, we first perform a Kruskal-Wallis test over the six tissues for each of the variables, and then a pairwise Dunn test. Sice we repeat this test over 22 variables, we have fixed the p-value threshold in 0.01.

# %% [markdown]
# #### Kruskal-Wallis pvalues

# %% [markdown]
# We are calculating the p-values from the Kruskal-Wallis test. First, we load the frame

# %%
require("dunn.test")
cellNumber <- 187
load(paste("../2_variables/frames",as.character(cellNumber), "cells_frame.RData", sep="/"))
colNames <- colnames(cells_frame)
# Out:
# Loading required package: dunn.test

# %% [markdown]
# and save the pvalues in an array

# %%
KWpvalue <- c()
for (j in seq(2,length(cells_frame))){
  colName <- colNames[j]
  kwAux <- as.numeric(kruskal.test(cells_frame[,colName] ~ cells_frame$type)[3])
  KWpvalue <- c(KWpvalue, kwAux)
    }

# %% [markdown]
# The variables whith a p-value greater or equal than 0.01 are

# %%
#Note the first entry in colNames is type and we do not want to take it.
colNames[c(FALSE,KWpvalue<=0.01)]
validCols <- colNames[c(FALSE, KWpvalue<=0.01)]
# Out:
#  [1] "PE.0.sub"          "PE.1.sub"          "landscape.0.2.sub"
#  [4] "landscape.0.5.sub" "lan.0.05.sub"      "lan.0.10.sub"
#  [7] "lan.0.15.sub"      "landscape.1.1.sub" "landscape.1.2.sub"
# [10] "lan.1.05.sub"      "max.0.1.1.sub"     "max.0.1.2.sub"
# [13] "max.0.1.3.sub"     "max.0.2.1.sub"     "max.0.2.2.sub"
# [16] "max.0.2.3.sub"     "MAX.0.2.10.sub"    "max.1.1.1.sub"
# [19] "max.1.2.1.sub"     "max.1.1.2.sub"     "MAX.1.1.02.sub"
# [22] "MAX.1.1.03.sub"    "PE.0.sup"          "PE.1.sup"
# [25] "landscape.0.2.sup" "lan.0.02.sup"      "lan.0.03.sup"
# [28] "landscape.1.1.sup" "landscape.1.2.sup" "lan.1.02.sup"
# [31] "max.0.1.1.sup"     "max.0.1.2.sup"     "MAX.0.1.02.sup"
# [34] "max.0.2.1.sup"     "max.0.2.2.sup"     "MAX.0.2.02.sup"
# [37] "max.1.1.1.sup"     "max.1.2.1.sup"     "MAX.1.2.02.sup"
# [40] "MAX.1.2.02.sup.1"  "PE.0.rips"         "len.1"
# [43] "len.2"             "len.5"             "LEN.15"
# [46] "LEN.20"            "max.0.1.1.rips"    "LEN.05"
# [49] "LEN.10"            "max.0.1.2.rips"    "max.0.1.3.rips"
# [52] "MAX.0.1.05.rips"   "MAX.0.1.10.rips"   "MAX.0.1.20.rips"
# [55] "MAX.0.1.50.rips"

# %% [markdown]
# The variables with a p-value greater than 0.01 are

# %%
#Note the first entry in colNames is type and we do not want to take it.
colNames[c(FALSE,KWpvalue>0.01)]
# Out:
# [1] "lan.1.03.sub" "LEN.50"

# %% [markdown]
# There are none variables with p-value greater than 0.01

# %% [markdown]
# #### Dunn Test

# %% [markdown]
# We run the Dunn test to compare pairwise the tissues.

# %%
colNames <- colnames(cells_frame)

# we perform the first dunn test before the loop to set the row names
colName <- colNames[2]
x1 <- cells_frame[cells_frame$type == 'cNT', colName]
x2 <- cells_frame[cells_frame$type == 'dWL', colName]
x3 <- cells_frame[cells_frame$type == 'dWP', colName]
x4 <- cells_frame[cells_frame$type == 'cEE', colName]
x5 <- cells_frame[cells_frame$type == 'dNP', colName]
w <- c(x1, x2, x3, x4, x5)
g <- factor(rep(1:5, c(length(x1),length(x2),length(x3),length(x4),length(x5))),
            labels = c("cNT","dWL","dWP",'cEE','dNP'))

P <- dunn.test(w, g)

Pvalues <- data.frame(P$P.adjusted)
colnames(Pvalues) <- c(colNames[2])
row.names(Pvalues) <- P[["comparisons"]]

for (j in seq(3,length(cells_frame))){
  colName <- colNames[j]
  x1 <- cells_frame[cells_frame$type == 'cNT', colName]
  x2 <- cells_frame[cells_frame$type == 'dWL', colName]
  x3 <- cells_frame[cells_frame$type == 'dWP', colName]
  x4 <- cells_frame[cells_frame$type == 'cEE', colName]
  x5 <- cells_frame[cells_frame$type == 'dNP', colName]
  w <- c(x1, x2, x3, x4, x5)
  g <- factor(rep(1:5, c(length(x1),length(x2),length(x3),length(x4),length(x5))),
              labels = c("cNT","dWL","dWP",'cEE','dNP'))
    
  P <- dunn.test(w, g)
  Pvalues[colName] <- P$P.adjusted
}
# Out:
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 50.5219, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.189594
#          |    0.0143*
#          |
#      dNP |   4.392217   2.463364
#          |    0.0000*    0.0069*
#          |
#      dWL |   5.605819   3.635652   0.944833
#          |    0.0000*    0.0001*     0.1724
#          |
#      dWP |   5.888650   3.906638   1.153480   0.207458
#          |    0.0000*    0.0000*     0.1244     0.4178
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 32.4956, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |  -2.854839
#          |    0.0022*
#          |
#      dNP |  -4.597567  -2.028169
#          |    0.0000*    0.0213*
#          |
#      dWL |  -4.057350  -1.311866   0.782441
#          |    0.0000*     0.0948     0.2170
#          |
#      dWP |  -5.026424  -2.293449  -0.095151  -0.944288
#          |    0.0000*    0.0109*     0.4621     0.1725
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 54.6056, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.807534
#          |     0.0353
#          |
#      dNP |   5.324236   3.813954
#          |    0.0000*    0.0001*
#          |
#      dWL |   5.492555   3.913171  -0.129340
#          |    0.0000*    0.0000*     0.4485
#          |
#      dWP |   5.562298   3.965472  -0.142640  -0.012181
#          |    0.0000*    0.0000*     0.4433     0.4951
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 47.7546, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.450812
#          |    0.0071*
#          |
#      dNP |   4.911992   2.752824
#          |    0.0000*    0.0030*
#          |
#      dWL |   5.245655   2.984521   0.055197
#          |    0.0000*    0.0014*     0.4780
#          |
#      dWP |   5.817135   3.555233   0.538682   0.512898
#          |    0.0000*    0.0002*     0.2951     0.3040
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 52.8648, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.176694
#          |    0.0148*
#          |
#      dNP |   5.226006   3.350025
#          |    0.0000*    0.0004*
#          |
#      dWL |   5.108978   3.125208  -0.403098
#          |    0.0000*    0.0009*     0.3434
#          |
#      dWP |   6.059136   4.100315   0.446129   0.908430
#          |    0.0000*    0.0000*     0.3278     0.1818
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 51.153, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.272015
#          |    0.0115*
#          |
#      dNP |   4.875037   2.888907
#          |    0.0000*    0.0019*
#          |
#      dWL |   5.676472   3.624514   0.514906
#          |    0.0000*    0.0001*     0.3033
#          |
#      dWP |   5.735106   3.657431   0.497216  -0.026557
#          |    0.0000*    0.0001*     0.3095     0.4894
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 62.3325, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.303174
#          |    0.0106*
#          |
#      dNP |   5.663320   3.684786
#          |    0.0000*    0.0001*
#          |
#      dWL |   5.808085   3.730909  -0.171110
#          |    0.0000*    0.0001*     0.4321
#          |
#      dWP |   6.367520   4.292427   0.289229   0.491717
#          |    0.0000*    0.0000*     0.3862     0.3115
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 48.8456, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.745016
#          |     0.0405
#          |
#      dNP |   5.028230   3.564784
#          |    0.0000*    0.0002*
#          |
#      dWL |   5.392022   3.872126   0.078256
#          |    0.0000*    0.0001*     0.4688
#          |
#      dWP |   5.097409   3.540521  -0.286898  -0.389178
#          |    0.0000*    0.0002*     0.3871     0.3486
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 41.4785, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   0.616670
#          |     0.2687
#          |
#      dNP |   3.998721   3.588833
#          |    0.0000*    0.0002*
#          |
#      dWL |   3.820871   3.387865  -0.394831
#          |    0.0001*    0.0004*     0.3465
#          |
#      dWP |   4.971537   4.599251   0.669246   1.136597
#          |    0.0000*    0.0000*     0.2517     0.1279
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 8.4722, df = 4, p-value = 0.08
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |  -1.552265
#          |     0.0603
#          |
#      dNP |  -0.710505   0.772954
#          |     0.2387     0.2198
#          |
#      dWL |  -1.566724  -0.039165  -0.798487
#          |     0.0586     0.4844     0.2123
#          |
#      dWP |   0.692708   2.370957   1.422125   2.371567
#          |     0.2442    0.0089*     0.0775    0.0089*
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 33.2628, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |  -3.878596
#          |    0.0001*
#          |
#      dNP |  -4.823618  -1.264131
#          |    0.0000*     0.1031
#          |
#      dWL |  -4.447310  -0.659396   0.634556
#          |    0.0000*     0.2548     0.2629
#          |
#      dWP |  -4.936395  -1.117160   0.229842  -0.439597
#          |    0.0000*     0.1320     0.4091     0.3301
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 8.762, df = 4, p-value = 0.07
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.459162
#          |    0.0070*
#          |
#      dNP |   1.593782  -0.733770
#          |     0.0555     0.2315
#          |
#      dWL |   2.397917  -0.026678   0.698750
#          |    0.0082*     0.4894     0.2424
#          |
#      dWP |   0.918482  -1.627139  -0.772668  -1.574002
#          |     0.1792     0.0519     0.2199     0.0577
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 41.6609, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   3.252133
#          |    0.0006*
#          |
#      dNP |   4.950628   2.009813
#          |    0.0000*    0.0222*
#          |
#      dWL |   5.835852   2.774269   0.592710
#          |    0.0000*    0.0028*     0.2767
#          |
#      dWP |   4.661248   1.488190  -0.632016  -1.310279
#          |    0.0000*     0.0684     0.2637     0.0951
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 44.0826, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.718047
#          |    0.0033*
#          |
#      dNP |   4.861504   2.438602
#          |    0.0000*    0.0074*
#          |
#      dWL |   5.616947   3.098353   0.470655
#          |    0.0000*    0.0010*     0.3189
#          |
#      dWP |   5.206631   2.628237  -0.005327  -0.512854
#          |    0.0000*    0.0043*     0.4979     0.3040
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 50.405, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2.941136
#          |    0.0016*
#          |
#      dNP |   5.512126   2.902508
#          |    0.0000*    0.0019*
#          |
#      dWL |   5.881631   3.145646   0.057123
#          |    0.0000*    0.0008*     0.4772
#          |
#      dWP |   5.465235   2.665746  -0.434507  -0.523248
#          |    0.0000*    0.0038*     0.3320     0.3004
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 47.7031, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   2
df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.387326
#          |     0.0827
#          |
#      dNP |   1.828641   0.560443
#          |     0.0337     0.2876
#          |
#      dWL |   4.104909   2.886672   2.126114
#          |    0.0000*    0.0019*    0.0167*
#          |
#      dWP |   4.554492   3.344900   2.536332   0.403835
#          |    0.0000*    0.0004*    0.0056*     0.3432
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 43.0461, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.288276
#          |     0.0988
#          |
#      dNP |   2.589172   1.454546
#          |    0.0048*     0.0729
#          |
#      dWL |   5.215200   4.160221   2.426319
#          |    0.0000*    0.0000*    0.0076*
#          |
#      dWP |   5.023292   3.944616   2.197459  -0.279748
#          |    0.0000*    0.0000*    0.0140*     0.3898
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 41.9332, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.538671
#          |     0.0619
#          |
#      dNP |   2.720773   1.347670
#          |    0.0033*     0.0889
#          |
#      dWL |   5.102037   3.780760   2.179575
#          |    0.0000*    0.0001*    0.0146*
#          |
#      dWP |   5.217702   3.885489   2.249593   0.041546
#          |    0.0000*    0.0001*    0.0122*     0.4834
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 3.1799, df = 4, p-value = 0.53
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |  -0.247934
#          |     0.4021
#          |
#      dNP |   1.303002   1.608342
#          |     0.0963     0.0539
#          |
#      dWL |   0.764982   1.064152  -0.598355
#          |     0.2221     0.1436     0.2748
#          |
#      dWP |   0.487871   0.777097  -0.888889  -0.299691
#          |     0.3128     0.2186     0.1870     0.3822
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 21.3107, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.711549
#          |     0.0435
#          |
#      dNP |   2.466753   0.912349
#          |    0.0068*     0.1808
#          |
#      dWL |   3.597938   2.015297   0.970527
#          |    0.0002*    0.0219*     0.1659
#          |
#      dWP |   4.110917   2.534015   1.433692   0.477511
#          |    0.0000*    0.0056*     0.0758     0.3165
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 34.3325, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.423009
#          |     0.0774
#          |
#      dNP |   1.886790   0.586510
#          |     0.0296     0.2788
#          |
#      dWL |   4.645505   3.419579   2.594928
#          |    0.0000*    0.0003*    0.0047*
#          |
#      dWP |   4.622167   3.378686   2.541545  -0.095834
#          |    0.0000*    0.0004*    0.0055*     0.4618
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 39.1528, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.018193
#          |     0.1543
#          |
#      dNP |   2.339742   1.457152
#          |    0.0096*     0.0725
#          |
#      dWL |   4.871831   4.078789   2.348184
#          |    0.0000*    0.0000*    0.0094*
#          |
#      dWP |   4.713220   3.902383   2.155752  -0.239863
#          |    0.0000*    0.0000*    0.0156*     0.4052
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 24.6226, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.707242
#          |     0.0439
#          |
#      dNP |   2.693994   1.154774
#          |    0.0035*     0.1241
#          |
#      dWL |   3.844310   2.279535   0.976696
#          |    0.0001*    0.0113*     0.1644
#          |
#      dWP |   4.362543   2.804310   1.441512   0.479173
#          |    0.0000*    0.0025*     0.0747     0.3159
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 26.6176, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.694323
#          |     0.0451
#          |
#      dNP |   2.689403   1.162594
#          |    0.0036*     0.1225
#          |
#      dWL |   3.986572   2.442952   1.120630
#          |    0.0000*    0.0073*     0.1312
#          |
#      dWP |   4.509581   2.973244   1.590095   0.481943
#          |    0.0000*    0.0015*     0.0559     0.3149
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 31.8196, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.597733
#          |     0.0551
#          |
#      dNP |   2.258639   0.805474
#          |    0.0120*     0.2103
#          |
#      dWL |   4.386846   2.965334   1.957505
#          |    0.0000*    0.0015*     0.0251
#          |
#      dWP |   4.748903   3.328006   2.275660   0.308554
#          |    0.0000*    0.0004*    0.0114*     0.3788
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 33.803, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.408244
#          |     0.0795
#          |
#      dNP |   2.191309   0.920169
#          |    0.0142*     0.1787
#          |
#      dWL |   4.525875   3.308788   2.163125
#          |    0.0000*    0.0005*    0.0153*
#          |
#      dWP |   4.727370   3.505387   2.325188   0.139597
#          |    0.0000*    0.0002*    0.0100*     0.4445
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 38.6472, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.310424
#          |     0.0950
#          |
#      dNP |   2.361166   1.193874
#          |    0.0091*     0.1163
#          |
#      dWL |   4.793587   3.692680   2.249486
#          |    0.0000*    0.0001*    0.0122*
#          |
#      dWP |   4.965461   3.860149   2.379929   0.104697
#          |    0.0000*    0.0001*    0.0087*     0.4583
#
# alpha = 0.05
# Reject Ho if p <= alpha/2
#   Kruskal-Wallis rank sum test
#
# data: w and g
# Kruskal-Wallis chi-squared = 42.9566, df = 4, p-value = 0
#
#
#                              Comparison of w by g
#                                 (No adjustment)
# Col Mean-|
# Row Mean |        cEE        cNT        dNP        dWL
# ---------+--------------------------------------------
#      cNT |   1.405168
#          |     0.0800
#          |
#      dNP |   2.713122   1.470186
#          |    0.0033*     0.0708
#          |
#      dWL |   5.064531   3.879918   2.150788
#          |    0.0000*    0.0001*    0.0157*
#          |
#      dWP |   5.260153   4.071317   2.299121   0.125194
#          |    0.0000*    0.0000*    0.0107*     0.4502
#
# alpha = 0.05
# Reject Ho if p <= alpha/2

# %% [markdown]
# We only consider the variables with a p-value greater than 0.01 in the Kruskal-Wallis test

# %%
cols <- colnames(Pvalues)%in%validCols

# %% [markdown]
# ##### Summary:

# %% [markdown]
# - cEE is differentiated from cNT only by the network distribution, and from dNP, dWL, dWP by both: network and centroids
# - cNT is differentiated from cEE and dNP only by the network distribution, and from dNP, dWL by both: network and centroids
# - dWL is differentiated from dNP by centroids (but only 1 variable); from cNT and cEE by both, network and centroids. There are not significant differences with dWP.
# - dWP is differentiated from dNP by centroids (but only 1 variable); from cNT and cEE by both, network and centroids. It cannot be differentiated from dWL.
# - dNP is differentiated from cNT by network distribution; from cEE by both, network and centroids and from dWL and dWP by centroids (but only 1 variable).

# %% [markdown]
# ###### cEE vs cNT

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["cEE - cNT",cols & Pvalues["cEE - cNT",]<=0.01]
# Out:
#           PE.1.sub   landscape.0.5.sub lan.1.05.sub max.0.1.1.sub max.0.1.2.sub
# cEE - cNT 0.00215293 0.007126708       5.253052e-05 0.00696307    0.0005727106
#           max.0.1.3.sub max.0.2.1.sub max.0.2.2.sub PE.0.sup
# cEE - cNT 0.003283421   0.001635052   0.006643707   0.007881721

# %% [markdown]
# We can find differences only in the contact network

# %% [markdown]
# ##### cEE vs dNP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cEE - dNP",cols & Pvalues["cEE - dNP",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "PE.1.sub"          "landscape.0.2.sub"
#  [4] "landscape.0.5.sub" "lan.0.05.sub"      "lan.0.10.sub"
#  [7] "lan.0.15.sub"      "landscape.1.1.sub" "landscape.1.2.sub"
# [10] "lan.1.05.sub"      "max.0.1.2.sub"     "max.0.1.3.sub"
# [13] "max.0.2.1.sub"     "max.0.2.2.sub"     "max.0.2.3.sub"
# [16] "MAX.0.2.10.sub"    "max.1.1.1.sub"     "max.1.2.1.sub"
# [19] "max.1.1.2.sub"     "MAX.1.1.02.sub"    "MAX.1.1.03.sub"
# [22] "PE.0.sup"          "landscape.0.2.sup" "lan.0.02.sup"
# [25] "landscape.1.1.sup" "landscape.1.2.sup" "lan.1.02.sup"
# [28] "max.0.1.1.sup"     "max.0.1.2.sup"     "MAX.0.1.02.sup"
# [31] "max.0.2.1.sup"     "max.0.2.2.sup"     "MAX.0.2.02.sup"
# [34] "max.1.1.1.sup"     "max.1.2.1.sup"     "MAX.1.2.02.sup"
# [37] "MAX.1.2.02.sup.1"  "PE.0.rips"         "len.1"
# [40] "len.2"             "LEN.15"            "LEN.20"
# [43] "max.0.1.1.rips"    "LEN.10"            "max.0.1.2.rips"
# [46] "max.0.1.3.rips"    "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### cNT vs dNP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cNT - dNP",cols & Pvalues["cNT - dNP",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "landscape.0.2.sub" "landscape.0.5.sub"
#  [4] "lan.0.05.sub"      "lan.0.10.sub"      "lan.0.15.sub"
#  [7] "landscape.1.1.sub" "landscape.1.2.sub" "max.0.1.3.sub"
# [10] "max.0.2.1.sub"     "max.0.2.2.sub"     "max.0.2.3.sub"
# [13] "MAX.0.2.10.sub"    "max.1.1.1.sub"     "max.1.2.1.sub"
# [16] "max.1.1.2.sub"     "MAX.1.1.02.sub"    "MAX.1.1.03.sub"
# [19] "landscape.0.2.sup" "lan.0.02.sup"      "landscape.1.1.sup"
# [22] "landscape.1.2.sup" "lan.1.02.sup"      "max.0.1.1.sup"
# [25] "max.0.1.2.sup"     "MAX.0.1.02.sup"    "max.0.2.1.sup"
# [28] "max.0.2.2.sup"     "MAX.0.2.02.sup"    "max.1.1.1.sup"
# [31] "max.1.2.1.sup"     "MAX.1.2.02.sup"    "MAX.1.2.02.sup.1"

# %% [markdown]
# We can find differences only in the contact network

# %% [markdown]
# ##### cEE vs dWL

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cEE - dWL",cols & Pvalues["cEE - dWL",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "PE.1.sub"          "landscape.0.2.sub"
#  [4] "landscape.0.5.sub" "lan.0.05.sub"      "lan.0.10.sub"
#  [7] "lan.0.15.sub"      "landscape.1.1.sub" "landscape.1.2.sub"
# [10] "lan.1.05.sub"      "max.0.1.1.sub"     "max.0.1.2.sub"
# [13] "max.0.1.3.sub"     "max.0.2.1.sub"     "max.0.2.2.sub"
# [16] "max.0.2.3.sub"     "MAX.0.2.10.sub"    "max.1.1.1.sub"
# [19] "max.1.2.1.sub"     "max.1.1.2.sub"     "MAX.1.1.02.sub"
# [22] "MAX.1.1.03.sub"    "PE.0.sup"          "landscape.0.2.sup"
# [25] "lan.0.02.sup"      "landscape.1.1.sup" "landscape.1.2.sup"
# [28] "lan.1.02.sup"      "max.0.1.1.sup"     "max.0.1.2.sup"
# [31] "MAX.0.1.02.sup"    "max.0.2.1.sup"     "max.0.2.2.sup"
# [34] "MAX.0.2.02.sup"    "max.1.1.1.sup"     "max.1.2.1.sup"
# [37] "MAX.1.2.02.sup"    "MAX.1.2.02.sup.1"  "PE.0.rips"
# [40] "len.1"             "len.2"             "len.5"
# [43] "LEN.15"            "LEN.20"            "max.0.1.1.rips"
# [46] "LEN.05"            "LEN.10"            "max.0.1.2.rips"
# [49] "max.0.1.3.rips"    "MAX.0.1.05.rips"   "MAX.0.1.10.rips"
# [52] "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### cNT vs dWL

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cNT - dWL",cols & Pvalues["cNT - dWL",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "landscape.0.2.sub" "landscape.0.5.sub"
#  [4] "lan.0.05.sub"      "lan.0.10.sub"      "lan.0.15.sub"
#  [7] "landscape.1.1.sub" "landscape.1.2.sub" "max.0.1.2.sub"
# [10] "max.0.1.3.sub"     "max.0.2.1.sub"     "max.0.2.2.sub"
# [13] "max.0.2.3.sub"     "MAX.0.2.10.sub"    "max.1.1.1.sub"
# [16] "max.1.2.1.sub"     "max.1.1.2.sub"     "MAX.1.1.02.sub"
# [19] "MAX.1.1.03.sub"    "PE.1.sup"          "landscape.0.2.sup"
# [22] "lan.0.02.sup"      "landscape.1.1.sup" "landscape.1.2.sup"
# [25] "lan.1.02.sup"      "max.0.1.1.sup"     "max.0.1.2.sup"
# [28] "MAX.0.1.02.sup"    "max.0.2.1.sup"     "max.0.2.2.sup"
# [31] "max.1.1.1.sup"     "max.1.2.1.sup"     "MAX.1.2.02.sup"
# [34] "MAX.1.2.02.sup.1"  "PE.0.rips"         "len.5"
# [37] "LEN.15"            "LEN.20"            "LEN.05"
# [40] "LEN.10"            "max.0.1.3.rips"    "MAX.0.1.05.rips"
# [43] "MAX.0.1.10.rips"   "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### dNP vs dWL

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dNP - dWL",cols & Pvalues["dNP - dWL",]<=0.01]
# Out:
#           LEN.15      LEN.05      LEN.10
# dNP - dWL 0.007626408 0.004730528 0.009432594

# %% [markdown]
# We can differentiate dNP from dWL only by LEN.10

# %% [markdown]
# ##### cEE vs dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cEE - dWP",cols & Pvalues["cEE - dWP",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "PE.1.sub"          "landscape.0.2.sub"
#  [4] "landscape.0.5.sub" "lan.0.05.sub"      "lan.0.10.sub"
#  [7] "lan.0.15.sub"      "landscape.1.1.sub" "landscape.1.2.sub"
# [10] "lan.1.05.sub"      "max.0.1.2.sub"     "max.0.1.3.sub"
# [13] "max.0.2.1.sub"     "max.0.2.2.sub"     "max.0.2.3.sub"
# [16] "MAX.0.2.10.sub"    "max.1.1.1.sub"     "max.1.2.1.sub"
# [19] "max.1.1.2.sub"     "MAX.1.1.02.sub"    "MAX.1.1.03.sub"
# [22] "PE.0.sup"          "landscape.0.2.sup" "lan.0.02.sup"
# [25] "lan.0.03.sup"      "landscape.1.1.sup" "landscape.1.2.sup"
# [28] "lan.1.02.sup"      "max.0.1.1.sup"     "max.0.1.2.sup"
# [31] "MAX.0.1.02.sup"    "max.0.2.1.sup"     "max.0.2.2.sup"
# [34] "MAX.0.2.02.sup"    "max.1.1.1.sup"     "max.1.2.1.sup"
# [37] "MAX.1.2.02.sup"    "MAX.1.2.02.sup.1"  "PE.0.rips"
# [40] "len.1"             "len.2"             "len.5"
# [43] "LEN.15"            "LEN.20"            "max.0.1.1.rips"
# [46] "LEN.05"            "LEN.10"            "max.0.1.2.rips"
# [49] "max.0.1.3.rips"    "MAX.0.1.05.rips"   "MAX.0.1.10.rips"
# [52] "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### cNT - dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
colnames(Pvalues["cNT - dWP",cols & Pvalues["cNT - dWP",]<=0.01])
# Out:
#  [1] "PE.0.sub"          "landscape.0.2.sub" "landscape.0.5.sub"
#  [4] "lan.0.05.sub"      "lan.0.10.sub"      "lan.0.15.sub"
#  [7] "landscape.1.1.sub" "landscape.1.2.sub" "max.0.1.3.sub"
# [10] "max.0.2.1.sub"     "max.0.2.2.sub"     "max.0.2.3.sub"
# [13] "MAX.0.2.10.sub"    "max.1.1.1.sub"     "max.1.2.1.sub"
# [16] "max.1.1.2.sub"     "MAX.1.1.02.sub"    "MAX.1.1.03.sub"
# [19] "PE.1.sup"          "landscape.0.2.sup" "lan.0.02.sup"
# [22] "lan.0.03.sup"      "landscape.1.1.sup" "landscape.1.2.sup"
# [25] "lan.1.02.sup"      "max.0.1.1.sup"     "max.0.1.2.sup"
# [28] "MAX.0.1.02.sup"    "max.0.2.1.sup"     "max.0.2.2.sup"
# [31] "MAX.0.2.02.sup"    "max.1.1.1.sup"     "max.1.2.1.sup"
# [34] "MAX.1.2.02.sup"    "MAX.1.2.02.sup.1"  "PE.0.rips"
# [37] "len.1"             "len.2"             "len.5"
# [40] "LEN.15"            "LEN.20"            "max.0.1.1.rips"
# [43] "LEN.05"            "LEN.10"            "max.0.1.2.rips"
# [46] "max.0.1.3.rips"    "MAX.0.1.05.rips"   "MAX.0.1.10.rips"
# [49] "MAX.0.1.20.rips"   "MAX.0.1.50.rips"

# %% [markdown]
# We can find differences in both, the contact network and in the centroid distribution

# %% [markdown]
# ##### dNP vs dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dNP - dWP",cols & Pvalues["dNP - dWP",]<=0.01]
# Out:
#           PE.0.rips   len.5      LEN.05      MAX.0.1.20.rips
# dNP - dWP 0.009961491 0.00560102 0.005518176 0.008657976

# %% [markdown]
# We cannot find differences between dNP from dWP only by len.5

# %% [markdown]
# ##### dWL vs dWP

# %% [markdown]
# The variables with a Dunn test smaller or equal than 0.01 are

# %%
Pvalues["dWL - dWP",cols & Pvalues["dWL - dWP",]<0.01]
# Out:
# [1] 0.007341815

# %%
Pvalues["dWL - dWP",cols & Pvalues["dWL - dWP",]<0.05]
# Out:
#           lan.0.03.sup lan.1.02.sup MAX.1.2.02.sup MAX.1.2.02.sup.1
# dWL - dWP 0.007341815  0.03575871   0.04358183     0.04358183

# %% [markdown]
# We cannot find differences between dNP and dWP

# %% [markdown]
# ## Differences between CVT path and Epithelial tissues

# %% [markdown]
# Some steps of the CVT paths are though to represent well the contact network of some epithelial tissues.
# In particular, cNT is similar to CVT001, dWL is similar to CVT004 and dWP is similar to CVT005.

# %% [markdown]
# We will perform Mann-Whitney U tests to see if we can find significant differences in their contact network and centroid distribution with our method.

# %%
variables <- colnames(cells_frame)
variables <- variables[seq(2,length(variables))]
CVTvsEPI <- data.frame(variables)

#calculate p-values of the Mann-Whitney U test
aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'cNT', colName]
  cvt = cells_frame[cells_frame$type == 'CVT001', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["001vsCNT"] <- aux

aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'dWL', colName]
  cvt = cells_frame[cells_frame$type == 'CVT004', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["004vsDWL"] <- aux

aux <- c()
for (colName in variables){
  epi = cells_frame[cells_frame$type == 'dWP', colName]
  cvt = cells_frame[cells_frame$type == 'CVT005', colName]
  aux <- c(aux, as.numeric(wilcox.test(epi,cvt, exact = FALSE)[3]))
}
CVTvsEPI["005vsDWP"] <- aux

# %% [markdown]
# ##### Summary:
# cNT and dWP can be differentiated from CVT001 and CVT005 respectively by both, network and centroid distribution. dWL can be differentiated from CVT004 only by network distribution

# %% [markdown]
# ##### cNT vs CVT001

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "001vsCNT"]<=0.01, c("variables", "001vsCNT")])
# Out:
#    variables       001vsCNT
# 1  PE.0.sub        0.0032315853
# 42 PE.0.rips       0.0071426558
# 45 len.5           0.0006976400
# 46 LEN.15          0.0007831876
# 47 LEN.20          0.0013767069
# 50 LEN.05          0.0017137487
# 54 MAX.0.1.05.rips 0.0008783885
# 55 MAX.0.1.10.rips 0.0009842247
# 56 MAX.0.1.20.rips 0.0007831876
# 57 MAX.0.1.50.rips 0.0007831876

# %% [markdown]
# We can find differences in both, the contact network and the centroid distribution

# %% [markdown]
# ##### dWL vs CVT004

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "004vsDWL"]<=0.01, c("variables", "004vsDWL")])
# Out:
#    variables       004vsDWL
# 42 PE.0.rips       0.008879300
# 43 len.1           0.001829083
# 49 max.0.1.1.rips  0.001829083
# 52 max.0.1.2.rips  0.003537936
# 53 max.0.1.3.rips  0.003177739
# 54 MAX.0.1.05.rips 0.009785073

# %% [markdown]
# ##### dWP vs CVT005

# %% [markdown]
# These are the variable for which the p-value of the Mann-Whitney U test is smaller than or equal to 0.01

# %%
as.vector(CVTvsEPI[CVTvsEPI[, "005vsDWP"]<=0.01, c("variables", "005vsDWP")])
# Out:
#    variables       005vsDWP
# NA NA                        NA
# 12 max.0.1.1.sub   8.542651e-03
# 42 PE.0.rips       9.624174e-05
# 43 len.1           3.416019e-04
# 44 len.2           2.125246e-03
# 46 LEN.15          4.381588e-03
# 47 LEN.20          2.363332e-03
# 49 max.0.1.1.rips  3.416019e-04
# 52 max.0.1.2.rips  5.519762e-04
# 53 max.0.1.3.rips  1.713749e-03
# 54 MAX.0.1.05.rips 3.962480e-03
# 55 MAX.0.1.10.rips 4.381588e-03
# 56 MAX.0.1.20.rips 2.125246e-03
# 57 MAX.0.1.50.rips 1.101765e-03
